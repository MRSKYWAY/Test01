# %%
import cv2
import mediapipe as mp
import numpy as np
from tkinter import *
from PIL import Image, ImageTk

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
def calculate_angles(a,b,c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)

    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)

    if angle >180.0:
        angle = 360-angle
    
    return angle

# %% [markdown]
# aPOSES (FLEXING BICEPS)

# %%
cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:  
  while cap.isOpened():
    ret,frame = cap.read()

    #recolor bgr to rgb
    image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    image.flags.writeable = False

    #making detection
    results = pose.process(image)

    #recolor rgb to bgr
    image.flags.writeable = True
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    counter = 0
    #Extract landmarks
    try: 
        landmarks = results.pose_landmarks.landmark
        elbow = list()
        shoulder = list()
        wrist = list()
        knee = list()
        ankle = list()
        hip = list()
        shoulder.append([landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y])
        elbow.append([landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y])
        wrist.append([landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y] )
        shoulder.append([landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y])
        elbow.append([landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y])
        wrist.append([landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y])
        #calculate angle
        angle = list()
        angle.append(calculate_angles(shoulder[0],elbow[0],wrist[0]))
        angle.append(calculate_angles(shoulder[1],elbow[1],wrist[1]))
        #visualize
        for i in range(len(angle)):
          cv2.putText(image,
          str(angle[i]),
          tuple(np.multiply(elbow[i],[640,480]).astype(int)),
          cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255,255,255),
            2,
            cv2.LINE_AA)
        counter = 0
        msg = ""
        if(angle[0]<80):
            counter += 1
        if(angle[1]<80):
            counter += 1    
        #detecting poses 
    except:
        pass
    #MESSAGE  BOX
    cv2.rectangle(image, (0,0), (475,75), (245,117,16), -1)
    cv2.putText(image, 'POSE', (15,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
    if(counter > 0):
        msg = "flexing biceps"
    else:
        msg = "Not Flexing Time to Hit Gym"
    cv2.putText(image, msg, 
                    (10,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    #reder detection
    mp_drawing.draw_landmarks(image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius= 2),
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness = 2, circle_radius= 2))
    cv2.namedWindow("yoga",cv2.WINDOW_NORMAL)
    cv2.resizeWindow("yoga",1920,1080)
    cv2.imshow('yoga', image)
    if cv2.waitKey(10) & 0xFF == ord('q'):
      break
  
  cap.release()
  cv2.destroyAllWindows()

# %% [markdown]
# ANGLES

# %%
cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:  
  while cap.isOpened():
  
    ret,frame = cap.read()

    #recolor bgr to rgb
    image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    image.flags.writeable = False

    #making detection
    results = pose.process(image)

    #recolor rgb to bgr
    image.flags.writeable = True
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)

    #Extract landmarks
    try: 
        landmarks = results.pose_landmarks.landmark
        elbow = list()
        shoulder = list()
        wrist = list()
        hip = list()
        knee = list()
        ankle = list()
        shoulder.append([landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y])
        elbow.append([landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y])
        wrist.append([landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y] )
        shoulder.append([landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y])
        elbow.append([landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y])
        wrist.append([landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y])
        hip.append([landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y])
        hip.append([landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y])
        knee.append([landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y])
        knee.append([landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y])
        ankle.append([landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y])
        ankle.append([landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y])
        #calculate angle
        angle = list()
        angle.append(calculate_angles(elbow[0],shoulder[0],hip[0]))
        angle.append(calculate_angles(elbow[1],shoulder[1],hip[1]))
        angle.append(calculate_angles(shoulder[0],elbow[0],wrist[0]))
        angle.append(calculate_angles(shoulder[1],elbow[1],wrist[1]))
        angle.append(calculate_angles(shoulder[0],hip[0],knee[0]))
        angle.append(calculate_angles(shoulder[1],hip[1],knee[1]))
        angle.append(calculate_angles(hip[0],knee[0],ankle[0]))
        angle.append(calculate_angles(hip[1],knee[1],ankle[1]))
        #visualize
        s = ""
        for i in range(len(angle)):
          cv2.putText(image,
          str(angle[i]),
          tuple(np.multiply(elbow[i],[640,480]).astype(int)),
          cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255,255,255),
            2,
            cv2.LINE_AA)
          
          cv2.putText(image,
          str(angle[i]),
          tuple(np.multiply(hip[i],[640,480]).astype(int)),
          cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255,255,255),
            2,
            cv2.LINE_AA)
          cv2.putText(image,
          str(angle[i]),
          tuple(np.multiply(knee[i],[640,480]).astype(int)),
          cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255,255,255),
            2,
            cv2.LINE_AA)
        #detecting poses 
    except:
        pass
  
    #reder detection
    mp_drawing.draw_landmarks(image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius= 2),
                              mp_drawing.DrawingSpec(color=(245,117,66), thickness = 2, circle_radius= 2))

    cv2.imshow('Mediapipe Feed', image)
    if cv2.waitKey(10) & 0xFF == ord('q'):
      break
  
  cap.release()
  cv2.destroyAllWindows()

# %% [markdown]
# POSES WORKING FINALLY!

# %%
cap = cv2.VideoCapture(0)
ret,frame = cap.read()
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:  
  while cap.isOpened():
  
    ret,frame = cap.read()
    

    #recolor bgr to rgb
    image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    image.flags.writeable = False

    #making detection
    results = pose.process(image)

    #recolor rgb to bgr
    image.flags.writeable = True
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)

    #Extract landmarks
    try: 
        landmarks = results.pose_landmarks.landmark
        elbow = list()
        shoulder = list()
        wrist = list()
        hip = list()
        knee = list()
        ankle = list()
        shoulder.append([landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y])
        elbow.append([landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y])
        wrist.append([landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y] )
        shoulder.append([landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y])
        elbow.append([landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y])
        wrist.append([landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y])
        hip.append([landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y])
        hip.append([landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y])
        knee.append([landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y])
        knee.append([landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y])
        ankle.append([landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y])
        ankle.append([landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y])
        #calculate angle
        angle = list()
        angle.append(calculate_angles(elbow[0],shoulder[0],hip[0]))
        angle.append(calculate_angles(elbow[1],shoulder[1],hip[1]))
        angle.append(calculate_angles(shoulder[0],elbow[0],wrist[0]))
        angle.append(calculate_angles(shoulder[1],elbow[1],wrist[1]))
        angle.append(calculate_angles(shoulder[0],hip[0],knee[0]))
        angle.append(calculate_angles(shoulder[1],hip[1],knee[1]))
        angle.append(calculate_angles(hip[0],knee[0],ankle[0]))
        angle.append(calculate_angles(hip[1],knee[1],ankle[1]))
        #visualize
        if(angle[0]>170 and angle[1]>170 and (angle[6] < 80 or angle[7] < 80)):
          msg = "tree pose"
        elif(angle[0] >170 and angle[1]>170 and (angle[6] <100 and angle[7] > 170) or (angle[7] <100 and angle[6] > 170)):
          msg = "warrior pose"
        elif(angle[0] >=90 and angle[1]>=90 and angle[4] >170 and angle[5] > 170):
          msg = "plank pose"
        elif(angle[2] >170 and angle[3]>170 and angle[4] <95 and angle[5] <95 ):
          msg = "staff pose"
        else:
          msg = "no pose"
        cv2.putText(image, msg, 
                    (10,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    except:
        pass
  
    #reder detection
    mp_drawing.draw_landmarks(image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(57, 255, 20), thickness=5, circle_radius= 3),
                              mp_drawing.DrawingSpec(color=(57, 255, 20), thickness = 5, circle_radius= 3))
    cv2.namedWindow("yoga",cv2.WINDOW_NORMAL)
    cv2.resizeWindow("yoga",1920,1080)
    cv2.imshow('yoga', image)
    if cv2.waitKey(10) & 0xFF == ord('q'):
      break
  
  cap.release()
  cv2.destroyAllWindows()

# %%
import tkinter as tk
root = tk.Tk()
root.geometry("700x450")
label = (root)
canvas = tk.Canvas(root, width=1200, height=700)
canvas.pack()
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read()
    img = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    canvas.create_image(0, 0, anchor= tk.NW, image=ImageTk.PhotoImage(Image.fromarray(img)))
    root.update()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# d:\bitchprojects\jupy\YogaPoseDetection.ipynb Cell 10 in <cell line: 32>()
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=31'>32</a> if __name__ == "__main__":
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=32'>33</a>     root = tk.Tk()
# ---> <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=33'>34</a>     MainWindow(root, cv2.VideoCapture(0))
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=34'>35</a>     root.mainloop()
#
# d:\bitchprojects\jupy\YogaPoseDetection.ipynb Cell 10 in MainWindow.__init__(self, window, cap)
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> self.canvas.grid(row=0, column=0)
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a> # Update image on canvas
# ---> <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a> self.update_image()
#
# d:\bitchprojects\jupy\YogaPoseDetection.ipynb Cell 10 in MainWindow.update_image(self)
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=23'>24</a> self.image = ImageTk.PhotoImage(self.image) # to ImageTk format
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=25'>26</a> # Update image
# ---> <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a> self.canvas.create_image(0, 0, anchor=tk.NW, image=self.image)
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=28'>29</a> # Repeat every 'interval' ms
#      <a href='vscode-notebook-cell:/d%3A/bitchprojects/jupy/YogaPoseDetection.ipynb#X20sZmlsZQ%3D%3D?line=29'>30</a> self.window.after(self.interval, self.update_image)
#
# File d:\Programs\Python\lib\tkinter\__init__.py:2790, in Canvas.create_image(self, *args, **kw)
#    2788 def create_image(self, *args, **kw):
#    2789     """Create image item with coordinates x1,y1."""
# -> 2790     return self._create('image', args, kw)
#
# File d:\Programs\Python\lib\tkinter\__init__.py:2776, in Canvas._create(self, itemType, args, kw)
#    2774 else:
#    2775     cnf = {}
# -> 2776 return self.tk.getint(self.tk.call(
#    2777     self._w, 'create', itemType,
#    2778     *(args + self._options(cnf, kw))))
#
# TclError: image "pyimage254" doesn't exist
